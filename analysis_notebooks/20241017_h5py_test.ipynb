# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from scipy.signal import welch

# %%
f.close()

# %%
file_name = r"E:\reheating_data\sphere_20250406\1_7e-8mbar\20250412_df_0.hdf5"
f = h5py.File(file_name, 'r')

dd = f['data']['channel_d'][:] * f['data']['channel_d'].attrs['adc2mv']/1000
ff = f['data']['channel_f'][:] * f['data']['channel_f'].attrs['adc2mv']/1000

plt.plot(dd)
plt.plot(ff)
f.close()

# %%
np.nonzero(gg > 10)
# Out:
# (array([], dtype=int64),)

# %%
plt.plot()
plt.xlim()
# Out:
# (322500.0, 3300000.0)

# %%
sphere = 'sphere_20250406'
dataset = '20250408_electric_calibration_5e-8mbar'
file_name = rf"E:\pulse_calibration\{sphere}\{dataset}/20250408_d_m12e_123khz_2vp2p_trapping_0.hdf5"
f = h5py.File(file_name, 'r')

print('X mean:', f['data'].attrs['channel_a_mean_mv'])
print('Y mean:', f['data'].attrs['channel_b_mean_mv'])
print('Z mean:', f['data'].attrs['channel_c_mean_mv'])
# print('Charge signal:', f['data'].attrs['channel_e_mean_mv'])
print('Z backscatter mean:', np.mean(f['data']['channel_d'] * f['data']['channel_d'].attrs['adc2mv']))
zz = f['data']['channel_d'] * f['data']['channel_d'].attrs['adc2mv']

print('Pressure:', f['data'].attrs['pressure_mbar'], 'mbar')
f.close()
# Out:
# X mean: 326.16846621600996
# Y mean: -137.49030418307035
# Z mean: 2650.468048168381
# Z backscatter mean: 16.83733899451684
# Pressure: 4.5e-08 mbar

# %%
dtt = 2e-6
ff, pp = welch(zz, fs=500000, nperseg=2**11)

plt.plot(ff/1000, pp*4e-16*1e-6, label='Z backward')
# plt.xlim(200000, 225000)
plt.yscale('log')
plt.xlabel('Frequency (kHz)')
plt.ylabel('Spectral density (V$^2$/Hz)')
# Out:
# Text(0, 0.5, 'Spectral density (V$^2$/Hz)')

# %%
file_idx = 1030
sphere = 'sphere_20250406'
dataset = '20250411_2e-8mbar_8e_alignment1_long'
prefix = '20250411_d_'

file_name = rf"E:\dm_data\{sphere}\{dataset}/{prefix}{file_idx}.hdf5"
f = h5py.File(file_name, 'r')

print('X mean:', f['data'].attrs['channel_a_mean_mv'])
print('Y mean:', f['data'].attrs['channel_b_mean_mv'])
print('Z mean:', f['data'].attrs['channel_c_mean_mv'])
# print('Charge signal:', f['data'].attrs['channel_e_mean_mv'])
print('Z backscatter mean:', np.mean(f['data']['channel_d'] * f['data']['channel_d'].attrs['adc2mv']))
zz = f['data']['channel_d'] * f['data']['channel_d'].attrs['adc2mv']

print('Pressure:', f['data'].attrs['pressure_mbar'], 'mbar')
f.close()
# Out:
# X mean: 14.823805154576249
# Y mean: 105.213204784285
# Z mean: 457.47624572486546
# Z backscatter mean: 19.795319632557185
# Pressure: 1.7e-08 mbar

# %%
plt.plot(zz)

# %%
from scipy.signal import welch

dtt = 2e-6
ff, pp = welch(zz, fs=500000, nperseg=2**11)

plt.plot(ff/1000, pp, label='Z backward')
# plt.xlim(200000, 225000)
plt.yscale('log')
plt.xlabel('Frequency (kHz)')
plt.ylabel('Spectral density (V$^2$/Hz)')
# Out:
# Text(0, 0.5, 'Spectral density (V$^2$/Hz)')

# %%
i_start = 0
i_end = 1009

sphere = 'sphere_20250406'
dataset = '20250411_2e-8mbar_8e_alignment1_long'
prefix = '20250411_d_'

aa, bb, cc = [np.empty(i_end - i_start + 1) for i in range(3)]
for file_idx in range(i_start, i_end+1):
    file_name = rf"E:\dm_data\{sphere}\{dataset}/{prefix}{file_idx}.hdf5"
    f = h5py.File(file_name, 'r')
    
    aa[file_idx-i_start] = f['data'].attrs['channel_a_mean_mv']
    bb[file_idx-i_start] = f['data'].attrs['channel_b_mean_mv']
    cc[file_idx-i_start] = f['data'].attrs['channel_c_mean_mv']

    f.close()

fig, ax = plt.subplots(figsize=(6, 4))

ax.plot(aa)
ax.plot(bb)
ax.plot(cc)
ax.set_ylim(-8000, 8000)

ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

print(np.mean(aa), np.mean(bb), np.mean(cc))
# Out:
# 185.2566343209294 -152.58922141807628 1629.4205792751975

# %%
698+423
# Out:
# 1121

# %%
file_dir = r'E:\dm_data\sphere_20250103\20250125_7e-9mbar_1e_alignment1_long'
for i in range(0, 423, 1):
    os.rename(os.path.join(file_dir, f'20250124_d_{i+1440}.hdf5'), os.path.join(file_dir, f'20250125_d_{i}.hdf5'))
