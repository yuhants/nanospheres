# %%
import RP_pico_control as rpc
import time

# %%
rpp = rpc.RPpico(port = 'COM3')
# Out:
# Connected to COM3

# %%
command = 'from machine import Pin'
rpp.send_command(command)
command = 'led = Pin("LED", Pin.OUT)'
rpp.send_command(command)
command = 'led.value(1)'
rpp.send_command(command)

# %%
command = 'led.value(0)'
rpp.send_command(command)

# %%
command = 'NSLEEP = Pin(21, Pin.OUT)'
rpp.send_command(command)
command = 'STEP = Pin(20, Pin.OUT)'
rpp.send_command(command)
command = 'DIR = Pin(19, Pin.OUT)'
rpp.send_command(command)

# %%
command = 'NSLEEP.value(1)'
rpp.send_command(command)

# %%
command = 'DIR.value(1)'
rpp.send_command(command)
time.sleep(1)
i = 0
while i < 250:
    command = 'STEP.value(1)'
    rpp.send_command(command)
    time.sleep(0.01)
    command = 'STEP.value(0)'
    rpp.send_command(command)
    i += 1

# %%
command = 'DIR.value(0)'
rpp.send_command(command)
time.sleep(1)
i = 0
while i < 270:
    command = 'STEP.value(1)'
    rpp.send_command(command)
    time.sleep(0.01)
    command = 'STEP.value(0)'
    rpp.send_command(command)
    i += 1

# %%
command = 'DIR.value(0)'
rpp.send_command(command)
command = 'NSLEEP.value(0)'
rpp.send_command(command)

# %%
rpp.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 from control_hugo import red_pitaya_control,red_pitaya_app
#
# ModuleNotFoundError: No module named 'control_hugo'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
